# %% [markdown]
# # Your Own Neural Network Model from Scratch
# - Write the model from scratch
#   - Data Import
#   - Preproessing
#   - Model Build
#   - Model Train
#   - Model Test
#   - Profitability Test
#
# # Requirements
# - In weekly question, please report the profitability of your model :)
